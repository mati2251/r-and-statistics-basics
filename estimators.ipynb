# %% [markdown]
# # Estymatory
# Estymatory to są funkcje, które przyjmują próbkę danych i zwracają wartość, która jest przybliżeniem parametru populacji. W przypadku próbki z rozkładu normalnego, estymator średniej populacji jest średnią próbkową. W przypadku próbki z rozkładu normalnego, estymator wariancji populacji jest wariancją próbkową.
# ## Estymator nieobciążony
# Estymator nieobciążony to taki którego wartość estymatora średnio jest równa wartości parametru populacji.
# ## Estymator obciążony
# Estymator obciążony to taki którego wartość średnio oscyluje wokół wartości parametru populacji.
# ## Badanie obciążenia estymatorów
# ### Losowanie populacji

# %%
population_size <- 1000
population <- runif(population_size, 0, 20)

# %% [markdown]
# ### Losowanie próby

# %%
sample_size <- 100
sample_count <- 200
samples <- replicate(sample_count, sample(population, sample_size))
samples
# Out:
#       [,1]        [,2]       [,3]       [,4]      [,5]      [,6]
#  [1,] 17.6518552   7.2450379  6.798649  15.670104  5.431343 12.624147
#  [2,]  1.0311631   6.8436530 10.794579  13.062386 12.470432  6.039970
#  [3,] 19.3316637  17.6938083 12.968862   3.042660 18.546219 12.737930
#  [4,]  7.2111527  15.9900369 10.356303  10.972052  9.418241 12.625010
#  [5,] 10.8004942  16.5752893 14.729121   5.907621  8.322996 11.736507
#  [6,] 18.8475881   7.5839576  2.720519   3.888330  7.559607  9.170515
#  [7,] 14.5874398   6.2307271  8.069914  10.212833 15.285968 19.790758
#  [8,]  8.0339113   1.0119564 11.210762  14.883771  8.560733 18.581850
#  [9,]  3.8606543  14.3913578 10.386183   1.940003 16.652347  5.523809
# [10,]  7.5139266  14.5920341 14.623333  11.999767 12.624147 18.367236
# [11,]  2.3798131  16.0947642 14.162873  18.397927  7.875596 18.397927
# [12,]  9.1809222   6.3334773  4.952665   6.955049  6.230727 15.012218
# [13,] 13.8915721  18.7937632 10.155154   7.051059 15.448695 13.705598
# [14,] 19.3499207   4.6375275 14.501500   7.215085  1.179944 10.483723
# [15,] 16.7341766  11.7823141 10.688653  13.643796 19.349921  8.580855
# [16,]  3.2550841  17.7799312  2.164684  19.378706 15.237052 18.420411
# [17,]  7.6633368  15.0122176  6.494589   6.333477 18.225675 11.160258
# [18,] 19.0894211  16.0530568 15.149880   5.493000 12.841475  7.019423
# [19,]  8.1295310   5.4780802 10.230557  17.827294 14.427602  8.345681
# [20,]  7.5112157   1.1799438 16.272463  12.960861 12.154513  3.888330
# [21,] 17.8272937  10.6543173 16.742461  19.156894  9.490062  2.969860
# [22,] 17.5558785   0.1189451  8.310878  19.936033 17.728499  9.256748
# [23,]  0.8761102  19.3247552  7.342760   3.639461  9.278526 18.416250
# [24,] 16.2558573  19.7509962 10.105512   3.869933  8.497694 10.610638
# [25,] 16.2424176  14.8671312  7.162205  17.698404 12.819033 14.393098
# [26,]  6.8662606  11.3854355  2.403198  16.254622 18.730334  2.357016
# [27,] 12.7909529  17.8005315  5.813904   6.569413 13.160498 12.367641
# [28,] 10.2680851  18.3923469  4.860101  14.154898 18.355046 11.633794
# [29,] 18.7303336   8.4976942 11.777550   4.191238 15.242751  6.201027
descriptive_statistics_population <- c(
    mean = mean(population),
    variance = variance_population(population),
    sd = sqrt(variance_population(population))
)
descriptive_statistics_population
# Out:
#      mean  variance        sd
# 10.089618 32.826380  5.729431

# %% [markdown]
# ### Estymatory

# %%
estimators <- list(
    mean_unbiased = apply(samples, 2, mean),
    variance_unbiased = apply(samples, 2, variance_population),
    variance_biased = apply(samples, 2, var)
)

# %% [markdown]
# ### Porównanie Estymatorów

# %%
rows  <- c("Estimator Mean", "Biased")
columns  <- c("Estimator mean", "Estimator variance", "Estimator unbiased variance")

average_estimators = sapply(estimators, mean)

biaseds = c(
    descriptive_statistics_population["mean"]- average_estimators["mean_unbiased"],
    descriptive_statistics_population["variance"]- average_estimators["variance_unbiased"],
    descriptive_statistics_population["variance"]- average_estimators["variance_biased"]
)
matrix(c(rbind(average_estimators, biaseds)), 2, 3, dimnames=list(rows, columns))
# Out:
#                Estimator mean Estimator variance Estimator unbiased variance
# Estimator Mean 10.06141996    32.4385128         32.76617452
# Biased          0.02819838     0.3878669          0.06020519

# %% [markdown]
# ### Wartości estymatorów

# %%
# get value by  name from list
hist(estimators$mean_unbiased)
hist(estimators$variance_unbiased)
hist(estimators$variance_biased)
# Out:
# Plot with title “Histogram of estimators$mean_unbiased”
# Plot with title “Histogram of estimators$variance_unbiased”
# Plot with title “Histogram of estimators$variance_biased”

# %% [markdown]
# ## Estymatory przedziałowe

# %%
alfa <- 0.05
mean <- descriptive_statistics_population["mean"]
sd <- descriptive_statistics_population["sd"]
quantile <- qnorm(1- alfa/2, 0, 1)
left_interval <- average_estimators + (quantile*sqrt(sd^2/sample_size))
right_interval <- average_estimators - (quantile*sqrt(sd^2/sample_size))
matrix(
    c(rbind(left_interval, right_interval, left_interval - right_interval, average_estimators, c(descriptive_statistics_population["mean"], descriptive_statistics_population["variance"], descriptive_statistics_population["variance"]))),
    5, 
    3, 
    dimnames=list(c("Left interval", "Right interval", "Interval long", "Average estimators", "Real values"), columns))
# Out:
#                    Estimator mean Estimator variance
# Left interval      11.184368      33.561461
# Right interval      8.938472      31.315565
# Interval long       2.245896       2.245896
# Average estimators 10.061420      32.438513
# Real values        10.089618      32.826380
#                    Estimator unbiased variance
# Left interval      33.889122
# Right interval     31.643227
# Interval long       2.245896
# Average estimators 32.766175
# Real values        32.826380

# %% [markdown]
# ### Estymator przedziałowy na wykresie

# %%
draw_ci_for_statistic = function(statistic, left_lim, right_lim, mean, sd){
    lim <- c(left_lim, right_lim)
    curve(dnorm(x, mean, sd), ylab = "Density", from=0, to=20, xlab = "x")
    abline(h = dnorm(mean, sd, 1) * c(0, 1), col = "blue", lty = c(1, 2))
    x <- seq(lim[1], lim[2], length = 100)
    y <- dnorm(x, mean, sd)
    polygon(c(lim[1], x, lim[2]), c(0, y, 0), col = "lightblue")
    abline(v = statistic, col = "red")
}
draw_ci_for_statistic(average_estimators["mean_unbiased"], left_interval["mean_unbiased"], right_interval["mean_unbiased"], descriptive_statistics_population["mean"], descriptive_statistics_population["sd"])
# Out:
# plot without title
